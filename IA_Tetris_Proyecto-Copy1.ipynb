# %% [markdown]
# # Colab install

# %%
# !pip install "stable-baselines3[extra]"
# !pip install tetris-gymnasium
# !pip install gymnasium[other]

# %%
file_path = r'S:\Universidad\Juegos_IA\.venv\Lib\site-packages\tetris_gymnasium\wrappers\observation.py'

with open(file_path, 'r') as f:
    content = f.read()
modified_content = content.replace("high=len(env.unwrapped.tetrominoes)", "high=255")
modified_content = modified_content.replace("self.render_scaling_factor", "20")

with open(file_path, 'w') as f:
    f.write(modified_content)

with open(file_path, 'r') as f:
    print(f.read())

# %%
file_path = r'S:\Universidad\Juegos_IA\.venv\Lib\site-packages\tetris_gymnasium\wrappers\grouped.py'

with open(file_path, 'r') as f:
    content = f.read()
modified_content = content.replace("high=env.unwrapped.height * env.unwrapped.width", "high=255")
#modified_content = modified_content.replace("self.render_scaling_factor", "20")
#modified_content = modified_content.replace("dtype=np.float32", "dtype=np.uint8")

with open(file_path, 'w') as f:
    f.write(modified_content)

with open(file_path, 'r') as f:
    print(f.read())

# %% [markdown]
# # Config

# %%
RENDER_ENV = False
LOAD_MODEL = False
new_size = (84,84) #(84,84) (96,136)
batch_size = 32
num_episodes = 9360 #56160 12 horas #4680 para 1 hora pc Seba
max_episode_steps = 500
fase1=0.75e6
fase2=1.25e6
fase3=3e6
total_steps = fase1+fase2+fase3
num_stacked_frames = 4
intervals = 4
Model = "PPO" # DQN o PPO
version = 11

#Hiperparametros Compartidos
LR = 2e-5 #2e-5
GAMMA = 0.999 #0.999
BATCH_SIZE=256 #256

#DQN Hiperparametros
EXPLORATION = 0.3
BUFFER_SIZE = 20000

#PPO Hiperparametros
N_STEPS = 4096
ENT_COEF = 0.01 
CLIP_RANGE = 0.2 #0.1

# %% [markdown]
# # imports

# %%
import importlib
import gymnasium as gym
import numpy as np
from tetris_gymnasium.envs.tetris import Tetris
from tetris_gymnasium.wrappers.observation import RgbObservation, FeatureVectorObservation
from tetris_gymnasium.wrappers.grouped import GroupedActionsObservations
from gymnasium.wrappers import TimeLimit, ResizeObservation, RecordVideo, FrameStackObservation, GrayscaleObservation
from stable_baselines3 import DQN, PPO
import os
from stable_baselines3.common.callbacks import CheckpointCallback, BaseCallback
from stable_baselines3.common.buffers import ReplayBuffer
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# # Funciones

# %%
def get_last_modified_file(directory_path):
    if not os.path.isdir(directory_path):
        print(f"Error: Directory '{directory_path}' does not exist.")
        return None
    files = [os.path.join(directory_path, f) for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))]
    if not files:
        return None
    files.sort(key=os.path.getmtime, reverse=True)
    return files[0]

target_directory = f"../Models_Saves/{Model}"  # Replace with your directory path
model_load_path = get_last_modified_file(target_directory)

if model_load_path:
    print(f"The last modified file is: {model_load_path}")
else:
    print("No files found in the directory or directory does not exist.")
# Out:
# The last modified file is: ../Models_Saves/PPO/PPO_V11_S5000000.0

# %%
try:
    os.mkdir("../Models_Saves")
except Exception as e:
    print(f"Error: {e}")
try:
    os.mkdir("../Models_Saves/PPO")
except Exception as e:
    print(f"Error: {e}")
try:
    os.mkdir("../Models_Saves/DQN")
except Exception as e:
    print(f"Error: {e}")
try:
    os.mkdir("../Models_Saves/PPO/checkpoint")
except Exception as e:
    print(f"Error: {e}")
try:
    os.mkdir("../Models_Saves/DQN/checkpoint")
except Exception as e:
    print(f"Error: {e}")
try:
    os.mkdir("../Video_Tetris_IA")
except Exception as e:
    print(f"Error: {e}")
try:
    os.mkdir("../Video_Tetris_IA/PPO")
except Exception as e:
    print(f"Error: {e}")
try:
    os.mkdir("../Video_Tetris_IA/DQN")
except Exception as e:
    print(f"Error: {e}")
try:
    os.mkdir("../Logs")
except Exception as e:
    print(f"Error: {e}")
try:
    os.mkdir("../Logs/PPO")
except Exception as e:
    print(f"Error: {e}")
try:
    os.mkdir("../Logs/DQN")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: [Errno 17] File exists: '../Models_Saves'
# Error: [Errno 17] File exists: '../Models_Saves/PPO'
# Error: [Errno 17] File exists: '../Models_Saves/DQN'
# Error: [Errno 17] File exists: '../Models_Saves/PPO/checkpoint'
# Error: [Errno 17] File exists: '../Models_Saves/DQN/checkpoint'
# Error: [Errno 17] File exists: '../Video_Tetris_IA'
# Error: [Errno 17] File exists: '../Video_Tetris_IA/PPO'
# Error: [Errno 17] File exists: '../Video_Tetris_IA/DQN'
# Error: [Errno 17] File exists: '../Logs'
# Error: [Errno 17] File exists: '../Logs/PPO'
# Error: [Errno 17] File exists: '../Logs/DQN'

# %%
def calc_max_height(mat):
  mat1 = np.rot90(np.rot90(mat))
  for i in range(len(mat1)):
    count = 0
    for col in mat1[i]:
      if col > 0:
        count+=1
    if count == 0:
      return i-1
  return 19

def calc_holes(mat,height):
  mat1 = np.rot90(np.rot90(np.rot90(mat)))
  holes = 0
  for row in mat1:
    for i in range(height+1):
      if row[i] == 0:
        holes += 1
  return holes

def calc_adj_col(mat, height):
  mat1 = np.rot90(np.rot90(np.rot90(mat)))
  prev_height = -1
  dif_count = 0
  for row in mat1:
    act_height = 0
    for i in range(height+1):
      if row[i] != 0:
        act_height = i+1
    if prev_height >= 0:
      dif_count+=(abs(prev_height-act_height))
    prev_height = act_height
  return dif_count

# %% [raw]
# class CustomRewardWrapper(gym.RewardWrapper):
#     #def __init__(self, env, holes_penalty = 0.005, height_penalty = 0.05, increase_height_penalty = 0.4, increase_holes_penalty = 0.2, dif_heigh_penalty = 0.03):
#     #Prometedor pero algo falta def __init__(self, env, holes_penalty = 0.000002, height_penalty = 0.00002, increase_height_penalty = 0.4, increase_holes_penalty = 0.2, dif_heigh_penalty = 0.00001):
#     def __init__(self, env, increase_height_penalty = 0.4, increase_holes_penalty = 0.4, dif_heigh_penalty = 0.2): #, holes_penalty = 0.000002, height_penalty = 0.00002
#         super(CustomRewardWrapper, self).__init__(env)
#         #self.holes_penalty = holes_penalty
#         #self.height_penalty = height_penalty
#         self.increase_height_penalty = increase_height_penalty
#         self.increase_holes_penalty = increase_holes_penalty
#         self.dif_heigh_penalty = dif_heigh_penalty
#
#     def reset(self, **kwargs):
#         obs, info = self.env.reset(**kwargs)
#
#         game_variables = self.env.unwrapped.get_state().board[:-4, 4:-4]
#         self.previous_max_height = calc_max_height(game_variables)
#         self.previous_holes = calc_holes(game_variables, self.previous_max_height)
#         self.previous_bumps = calc_adj_col(game_variables, self.previous_max_height)
#
#         return obs, info
#
#     def reward(self, reward):
#         #print(f"Reward original: {reward}")
#         # Probar mayor penalizacion de agujeros
#         custom_reward = reward
#
#         match int(reward):
#             case 1:
#                 custom_reward+=0.5
#             case 2:
#                 custom_reward+=2
#             case 3:
#                 custom_reward+=4
#             case 4:
#                 custom_reward+=7
#
#         game_variables = self.env.unwrapped.get_state().board[:-4, 4:-4]
#
#         if game_variables.any():
#             # Calcula la altura maxima actual
#             current_max_height = calc_max_height(game_variables)
#             # Calcula ls espacios vacios entre la base y la altura
#             current_holes = calc_holes(game_variables, current_max_height)
#             #Calcula la diferencia de altura entre las columnas adyacentes y las suma
#             current_height_dif = calc_adj_col(game_variables, current_max_height)
#             # #Penalizacion constante por altura
#             # custom_reward -= current_max_height*self.height_penalty
#             # #Penalizacion constante por agujeros
#             # custom_reward -= current_holes*self.holes_penalty
#             # #Penalizacion constante por diferencia de altura entre columnas
#             # custom_reward -= current_height_dif*self.dif_heigh_penalty
#             # Penalizacion y recompensa por aumentar altura o disminuir altura respectivamente
#             bumps_change = current_height_dif-self.previous_bumps
#             if bumps_change > 0:
#                 custom_reward -= bumps_change*self.dif_heigh_penalty
#             height_change=current_max_height-self.previous_max_height
#             if height_change > 0:
#                 custom_reward -= height_change*self.increase_height_penalty
#             #Penalizacion y recompensa por aumentar agujeros o disminuir agujeros respectivamente
#             holes_change = current_holes-self.previous_holes
#             if holes_change > 0:
#                 custom_reward -= holes_change*self.increase_holes_penalty
#             elif holes_change < 0:
#                 custom_reward += abs(holes_change)*self.increase_holes_penalty
#             #Actualiza valores previos para el siguiente paso
#             self.previous_holes = current_holes
#             self.previous_max_height = current_max_height
#             self.previous_bumps = current_height_dif
#
#         return custom_reward

# %%
class CustomRewardWrapper(gym.Wrapper):
    #def __init__(self, env, holes_penalty = 0.005, height_penalty = 0.05, increase_height_penalty = 0.4, increase_holes_penalty = 0.2, dif_heigh_penalty = 0.03):
    #Prometedor pero algo falta def __init__(self, env, holes_penalty = 0.000002, height_penalty = 0.00002, increase_height_penalty = 0.4, increase_holes_penalty = 0.2, dif_heigh_penalty = 0.00001):
    def __init__(self, env, increase_height_penalty = 1.0, increase_holes_penalty = 1.0, dif_heigh_penalty = 0.2, line1=0.5, line2=3, line3=6, line4=15, gameover=50, trunc=10): #, holes_penalty = 0.000002, height_penalty = 0.00002
        super(CustomRewardWrapper, self).__init__(env)
        #self.holes_penalty = holes_penalty
        #self.height_penalty = height_penalty
        self.increase_height_penalty = increase_height_penalty
        self.increase_holes_penalty = increase_holes_penalty
        self.dif_heigh_penalty = dif_heigh_penalty
        self.line1 = line1
        self.line2 = line2
        self.line3 = line3
        self.line4 = line4
        self.gameover = gameover
        self.trunc = trunc

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)

        game_variables = self.env.unwrapped.get_state().board[:-4, 4:-4]
        self.previous_max_height = calc_max_height(game_variables)
        self.previous_holes = calc_holes(game_variables, self.previous_max_height)
        self.previous_bumps = calc_adj_col(game_variables, self.previous_max_height)

        return obs, info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        #print(f"Reward original: {reward}")
        # Probar mayor penalizacion de agujeros
        custom_reward = reward

        match int(reward):
            case 1:
                custom_reward+=self.line1
            case 2:
                custom_reward+=self.line2
            case 3:
                custom_reward+=self.line3
            case 4:
                custom_reward+=self.line4
        
        game_variables = self.env.unwrapped.get_state().board[:-4, 4:-4]

        if game_variables.any():
            # Calcula la altura maxima actual
            current_max_height = calc_max_height(game_variables)
            # Calcula ls espacios vacios entre la base y la altura
            current_holes = calc_holes(game_variables, current_max_height)
            #Calcula la diferencia de altura entre las columnas adyacentes y las suma
            current_height_dif = calc_adj_col(game_variables, current_max_height)
            # #Penalizacion constante por altura
            # custom_reward -= current_max_height*self.height_penalty
            # #Penalizacion constante por agujeros
            # custom_reward -= current_holes*self.holes_penalty
            # #Penalizacion constante por diferencia de altura entre columnas
            # custom_reward -= current_height_dif*self.dif_heigh_penalty
            # Penalizacion y recompensa por aumentar altura o disminuir altura respectivamente
            bumps_change = current_height_dif-self.previous_bumps
            if bumps_change > 0:
                custom_reward -= bumps_change*self.dif_heigh_penalty
            height_change=current_max_height-self.previous_max_height
            if height_change > 0:
                custom_reward -= height_change*self.increase_height_penalty
            #Penalizacion y recompensa por aumentar agujeros o disminuir agujeros respectivamente
            holes_change = current_holes-self.previous_holes
            if holes_change > 0:
                custom_reward -= holes_change*self.increase_holes_penalty
            elif holes_change < 0:
                custom_reward += abs(holes_change)*self.increase_holes_penalty
            #Actualiza valores previos para el siguiente paso
            self.previous_holes = current_holes
            self.previous_max_height = current_max_height
            self.previous_bumps = current_height_dif
        if terminated:
            custom_reward -= self.gameover
        elif truncated:
            custom_reward += self.trunc
        
        return obs, custom_reward, terminated, truncated, info

# %% [markdown]
# # Make single ENV

# %%
def make_env(*, game, obs_type, render_mode, record = True, increase_height_penalty = 1.0, increase_holes_penalty = 1.0, dif_heigh_penalty = 0.2, line1=0.5, line2=3, line3=6, line4=15, gameover=50, trunc=10, fase, **kwargs):
    env = gym.make(game,render_mode=render_mode, **kwargs)
    env = TimeLimit(env, max_episode_steps=max_episode_steps)
    if obs_type == "RGB":
        env = RgbObservation(env)
        env = ResizeObservation(env, new_size)
        env = GrayscaleObservation(env)
        env = FrameStackObservation(env, stack_size=num_stacked_frames)
    elif obs_type == "FV":
        env = FeatureVectorObservation(env)
        env = FrameStackObservation(env, stack_size=num_stacked_frames)
    elif obs_type == "GA":
        env = GroupedActionsObservations(env, observation_wrappers=[FeatureVectorObservation(env)]) #
        #env = ResizeObservation(env, new_size)
        #env = FrameStackObservation(env, stack_size=num_stacked_frames)
    if record:
      env = Monitor(env, f'../Logs/{Model}/{Model}_V{version}_S{total_steps}_Fase{fase}.csv')
    env = CustomRewardWrapper(env, increase_height_penalty = increase_height_penalty, increase_holes_penalty = increase_holes_penalty, dif_heigh_penalty = dif_heigh_penalty, line1=line1, line2=line2, line3=line3, line4=line4, gameover=gameover, trunc=trunc)
    checkpoint_callback = CheckpointCallback(
        save_freq=100000,
        save_path=f'../Models_Saves/{Model}/checkpoint',
        name_prefix=f'{Model}_tetris_step'
    )
    env.reset(seed=42)
    return env

# %% [markdown]
# # Make Vec Env

# %% [raw]
# def make_env(*, game, obs_type, render_mode, record = True, **kwargs):
#     wrapper_list = []
#     if obs_type == "RGB":
#         wrapper_list = [
#             (RgbObservation, {}),
#             (ResizeObservation, {"shape": new_size}),
#             (GrayscaleObservation, {}),
#             (FrameStackObservation, {"stack_size": num_stacked_frames}),
#         ]
#     elif obs_type == "FV":
#         wrapper_list = [
#             (FeatureVectorObservation, {}),
#             (FrameStackObservation, {"stack_size": num_stacked_frames}),
#         ]
#     env = make_vec_env(game, n_envs=4,wrapper_class=wrapper_list)
#     if record:
#       env = Monitor(env, f'../Logs/{Model}/{Model}_V{version}_S{total_steps}.csv')
#     env = CustomRewardWrapper(env)
#     checkpoint_callback = CheckpointCallback(
#         save_freq=100000,
#         save_path=f'../Models_Saves/{Model}/checkpoint',
#         name_prefix=f'{Model}_tetris_step'
#     )
#     env.reset(seed=42)
#     return env

# %% [raw]
# from stable_baselines3.common.vec_env import SubprocVecEnv
# def make_env(game, obs_type, render_mode, record = False, num_stacked_frames=4, **kwargs):
#     # 1. Instantiate the base environment
#     # Note: We are creating a single environment instance here
#     env = gym.make(game, render_mode=render_mode)
#
#     # 2. Define the list of wrappers (classes and kwargs)
#     if obs_type == "FV":
#         wrapper_list = [
#             (FeatureVectorObservation, {}),
#             # Note: FrameStack must be applied AFTER feature extraction
#             (FrameStackObservation, {"stack_size": num_stacked_frames}),
#             (RecordVideo, {"video_folder": f'../Video_Tetris_IA/{Model}', "name_prefix": f'{Model}_eval-V{version}-Trained_steps_{total_steps}', 'episode_trigger': lambda x: True}),
#         ]
#
#     # 3. Iterate through the list and apply each wrapper sequentially
#     for wrapper_class, wrapper_kwargs in wrapper_list:
#         # Wrap the current 'env' instance with the wrapper class and kwargs
#         env = wrapper_class(env, **wrapper_kwargs)
#
#     # 4. Use lambda function to create the environment functions required by VecEnv
#     # We pass the already-wrapped environment's *creation logic* to make_vec_env
#     # Note: We are now passing the *function* that creates the wrapped environment
#     # instead of trying to use make_vec_env's 'wrapper_class' argument.
#
#     # Define a function (closure) that returns the fully wrapped environment
#     def env_factory():
#         # Re-create the environment and apply all wrappers
#         current_env = gym.make(game, render_mode=render_mode)
#         if obs_type == "FV":
#             for wrapper_class, wrapper_kwargs in wrapper_list:
#                 current_env = wrapper_class(current_env, **wrapper_kwargs)
#         return current_env
#
#     # 5. Create the VecEnv using the function
#     # The list comprehension in make_vec_env will call env_factory N times.
#     vec_env = make_vec_env(env_factory, n_envs=4, vec_env_cls=SubprocVecEnv, **kwargs)
#
#     # 6. Apply VecMonitor if needed (it takes the VecEnv object)
#     if record:
#       # Use VecMonitor for VecEnvs instead of Monitor for single envs
#       from stable_baselines3.common.monitor import Monitor as VecMonitor
#       # Assuming 'Model', 'version', 'total_steps' are defined elsewhere
#       vec_env = VecMonitor(vec_env, f'../Logs/{Model}/{Model}_V{version}_S{total_steps}.csv')
#
#     return vec_env

# %% [markdown]
# # Training

# %%
try:
  env.close()
except:
  print('no hay env para cerrar')
# Out:
# no hay env para cerrar

# %%
env = make_env(game = "tetris_gymnasium/Tetris", render_mode="rgb_array", obs_type="RGB", increase_height_penalty = 1.5, increase_holes_penalty = 1.5, dif_heigh_penalty = 0.05, line1=0.5, line2=0.5, line3=0.5, line4=0.5, gameover=50, trunc=10, fase=1)
if Model == "DQN":
    model = DQN("CnnPolicy", env, buffer_size=BUFFER_SIZE, verbose=1, exploration_fraction=EXPLORATION, exploration_final_eps = 0.05, learning_rate=LR, batch_size=BATCH_SIZE, gamma=GAMMA) # para Mlp usar FeatureVectorObservation para Cnn usar RgbObservation
else:
    model = PPO("CnnPolicy", env, verbose=1, n_steps=N_STEPS, clip_range=CLIP_RANGE, ent_coef=ENT_COEF, gamma=GAMMA, batch_size=BATCH_SIZE, learning_rate=LR) # para Mlp usar FeatureVectorObservation para Cnn

model.learn(total_timesteps=fase1, log_interval=4, progress_bar=True)
model.save(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}")
env.close()
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# Output()
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.2        |
# |    ep_rew_mean          | 10.8        |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 4           |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013011232 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | -0.0129     |
# |    learning_rate        | 2e-05       |
# |    loss                 | 227         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00289    |
# |    value_loss           | 584         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | 11.3        |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 8           |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006273399 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 125         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00222     |
# |    value_loss           | 278         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 150        |
# |    ep_rew_mean          | 11.6       |
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 12         |
# |    time_elapsed         | 435        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01176231 |
# |    clip_fraction        | 0.146      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.88      |
# |    explained_variance   | 0.885      |
# |    learning_rate        | 2e-05      |
# |    loss                 | 111        |
# |    n_updates            | 110        |
# |    policy_gradient_loss | 0.00327    |
# |    value_loss           | 234        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | 12.1        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 16          |
# |    time_elapsed         | 578         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.019699734 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 127         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00842     |
# |    value_loss           | 217         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | 12.3        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 20          |
# |    time_elapsed         | 718         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008568754 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 105         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.0019      |
# |    value_loss           | 201         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 138         |
# |    ep_rew_mean          | 11.5        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 24          |
# |    time_elapsed         | 858         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006398381 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 90.7        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00172     |
# |    value_loss           | 216         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 12.3        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 28          |
# |    time_elapsed         | 993         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.010286888 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 91          |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00554     |
# |    value_loss           | 194         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 12.3        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 32          |
# |    time_elapsed         | 1128        |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.010167757 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 93          |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00127    |
# |    value_loss           | 169         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 12.8        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 36          |
# |    time_elapsed         | 1263        |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.009195275 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 88.2        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00146    |
# |    value_loss           | 175         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 13.2        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 40          |
# |    time_elapsed         | 1399        |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.012907794 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 55.5        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00166     |
# |    value_loss           | 134         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 175         |
# |    ep_rew_mean          | 14.1        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 44          |
# |    time_elapsed         | 1532        |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.007602522 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 70.8        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00273    |
# |    value_loss           | 137         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | 14.7        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 48          |
# |    time_elapsed         | 1665        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.007737349 |
# |    clip_fraction        | 0.0687      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 79.2        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 9.74e-05    |
# |    value_loss           | 163         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | 14.5        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 52          |
# |    time_elapsed         | 1796        |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.016545348 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 56.3        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00146     |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 190         |
# |    ep_rew_mean          | 14.7        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 56          |
# |    time_elapsed         | 1927        |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.014823441 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 62.1        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 131         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 15.8         |
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 60           |
# |    time_elapsed         | 2057         |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0063505033 |
# |    clip_fraction        | 0.0803       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.904        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 53.8         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | 0.000227     |
# |    value_loss           | 135          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 15.8         |
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 64           |
# |    time_elapsed         | 2186         |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0071031395 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.901        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 53.2         |
# |    n_updates            | 630          |
# |    policy_gradient_loss | 0.00216      |
# |    value_loss           | 119          |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 203       |
# |    ep_rew_mean          | 16.2      |
# | time/                   |           |
# |    fps                  | 120       |
# |    iterations           | 68        |
# |    time_elapsed         | 2315      |
# |    total_timesteps      | 278528    |
# | train/                  |           |
# |    approx_kl            | 0.0080301 |
# |    clip_fraction        | 0.101     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.34     |
# |    explained_variance   | 0.927     |
# |    learning_rate        | 2e-05     |
# |    loss                 | 46.8      |
# |    n_updates            | 670       |
# |    policy_gradient_loss | -0.000618 |
# |    value_loss           | 100       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 195        |
# |    ep_rew_mean          | 16         |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 72         |
# |    time_elapsed         | 2444       |
# |    total_timesteps      | 294912     |
# | train/                  |            |
# |    approx_kl            | 0.00424005 |
# |    clip_fraction        | 0.141      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.904      |
# |    learning_rate        | 2e-05      |
# |    loss                 | 61.5       |
# |    n_updates            | 710        |
# |    policy_gradient_loss | -5.07e-05  |
# |    value_loss           | 108        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | 15.8        |
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 76          |
# |    time_elapsed         | 2572        |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.008488765 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 56.8        |
# |    n_updates            | 750         |
# |    policy_gradient_loss | -2.5e-05    |
# |    value_loss           | 126         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | 15.9         |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 80           |
# |    time_elapsed         | 2701         |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0073297145 |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.54        |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 47.2         |
# |    n_updates            | 790          |
# |    policy_gradient_loss | 0.000759     |
# |    value_loss           | 108          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 187          |
# |    ep_rew_mean          | 15.3         |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 84           |
# |    time_elapsed         | 2830         |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0049254224 |
# |    clip_fraction        | 0.0918       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 70.9         |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 126          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 189          |
# |    ep_rew_mean          | 15.2         |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 88           |
# |    time_elapsed         | 2960         |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0053295908 |
# |    clip_fraction        | 0.0841       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.911        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 65.7         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.000231    |
# |    value_loss           | 119          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 192         |
# |    ep_rew_mean          | 15.9        |
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 92          |
# |    time_elapsed         | 3089        |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.015574375 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 43.3        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | 0.00111     |
# |    value_loss           | 87.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | 15.6        |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 96          |
# |    time_elapsed         | 3218        |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.007922502 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 51.3        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.000209   |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 202         |
# |    ep_rew_mean          | 16.1        |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 100         |
# |    time_elapsed         | 3347        |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.008057347 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 41.6        |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.000524   |
# |    value_loss           | 87.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 212         |
# |    ep_rew_mean          | 16.8        |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 104         |
# |    time_elapsed         | 3477        |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.005787501 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 2e-05       |
# |    loss                 | 45.9        |
# |    n_updates            | 1030        |
# |    policy_gradient_loss | 0.002       |
# |    value_loss           | 95.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 202          |
# |    ep_rew_mean          | 16.4         |
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 108          |
# |    time_elapsed         | 3606         |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0036821654 |
# |    clip_fraction        | 0.0728       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 48           |
# |    n_updates            | 1070         |
# |    policy_gradient_loss | 0.000477     |
# |    value_loss           | 89.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 15.7        |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 112         |
# |    time_elapsed         | 3736        |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.006709565 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 47.1        |
# |    n_updates            | 1110        |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 16.2        |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 116         |
# |    time_elapsed         | 3866        |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.008297016 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 43.1        |
# |    n_updates            | 1150        |
# |    policy_gradient_loss | 0.000185    |
# |    value_loss           | 84.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 206         |
# |    ep_rew_mean          | 16.5        |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 120         |
# |    time_elapsed         | 3995        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.011994085 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 2e-05       |
# |    loss                 | 39          |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | 0.00155     |
# |    value_loss           | 100         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 203         |
# |    ep_rew_mean          | 15.8        |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 124         |
# |    time_elapsed         | 4125        |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.012284761 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 45.2        |
# |    n_updates            | 1230        |
# |    policy_gradient_loss | -0.000316   |
# |    value_loss           | 83.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 221         |
# |    ep_rew_mean          | 16.4        |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 128         |
# |    time_elapsed         | 4254        |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.008693625 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 2e-05       |
# |    loss                 | 31.3        |
# |    n_updates            | 1270        |
# |    policy_gradient_loss | 0.00134     |
# |    value_loss           | 82.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 132         |
# |    time_elapsed         | 4384        |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.012361511 |
# |    clip_fraction        | 0.0994      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 26.6        |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.0024     |
# |    value_loss           | 73.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 223         |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 136         |
# |    time_elapsed         | 4514        |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.005005188 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 33.8        |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | 0.0015      |
# |    value_loss           | 86.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 221         |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 140         |
# |    time_elapsed         | 4643        |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.005747089 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 30.7        |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.00109    |
# |    value_loss           | 80.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 215          |
# |    ep_rew_mean          | 16.7         |
# | time/                   |              |
# |    fps                  | 123          |
# |    iterations           | 144          |
# |    time_elapsed         | 4772         |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0057152505 |
# |    clip_fraction        | 0.139        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 51.2         |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | 4.29e-05     |
# |    value_loss           | 109          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 221         |
# |    ep_rew_mean          | 16.7        |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 148         |
# |    time_elapsed         | 4901        |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.008255405 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 40.3        |
# |    n_updates            | 1470        |
# |    policy_gradient_loss | 0.00109     |
# |    value_loss           | 85.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 231         |
# |    ep_rew_mean          | 17.3        |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 152         |
# |    time_elapsed         | 5030        |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.009689013 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 43.2        |
# |    n_updates            | 1510        |
# |    policy_gradient_loss | -2.71e-05   |
# |    value_loss           | 88.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 222         |
# |    ep_rew_mean          | 16.6        |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 156         |
# |    time_elapsed         | 5159        |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.009557866 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 30.4        |
# |    n_updates            | 1550        |
# |    policy_gradient_loss | -0.000752   |
# |    value_loss           | 85.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | 17           |
# | time/                   |              |
# |    fps                  | 123          |
# |    iterations           | 160          |
# |    time_elapsed         | 5289         |
# |    total_timesteps      | 655360       |
# | train/                  |              |
# |    approx_kl            | 0.0043949867 |
# |    clip_fraction        | 0.0781       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 39.1         |
# |    n_updates            | 1590         |
# |    policy_gradient_loss | 0.000374     |
# |    value_loss           | 78.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 234         |
# |    ep_rew_mean          | 16.9        |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 164         |
# |    time_elapsed         | 5419        |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.008321684 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 40.6        |
# |    n_updates            | 1630        |
# |    policy_gradient_loss | 0.00108     |
# |    value_loss           | 76.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 226         |
# |    ep_rew_mean          | 16.4        |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 168         |
# |    time_elapsed         | 5549        |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.011143137 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 42.4        |
# |    n_updates            | 1670        |
# |    policy_gradient_loss | 0.000615    |
# |    value_loss           | 82.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 172         |
# |    time_elapsed         | 5678        |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.009196468 |
# |    clip_fraction        | 0.099       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 36.8        |
# |    n_updates            | 1710        |
# |    policy_gradient_loss | 0.000132    |
# |    value_loss           | 69.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 230         |
# |    ep_rew_mean          | 16.7        |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 176         |
# |    time_elapsed         | 5808        |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.006395052 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 35.9        |
# |    n_updates            | 1750        |
# |    policy_gradient_loss | 0.000654    |
# |    value_loss           | 64.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | 16.8        |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 180         |
# |    time_elapsed         | 5938        |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.009627204 |
# |    clip_fraction        | 0.0973      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 2e-05       |
# |    loss                 | 32.6        |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.000511   |
# |    value_loss           | 87.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 234         |
# |    ep_rew_mean          | 17.3        |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 184         |
# |    time_elapsed         | 6068        |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.013276795 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 29.7        |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | 0.00157     |
# |    value_loss           | 62.3        |
# -----------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
env = make_env(game = "tetris_gymnasium/Tetris", render_mode="rgb_array", obs_type="RGB", increase_height_penalty = 1.0, increase_holes_penalty = 2.0, dif_heigh_penalty = 0.05, line1=0.5, line2=0.5, line3=0.5, line4=0.5, gameover=50, trunc=10, fase=2)
if Model == "DQN":
    model = DQN.load(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}", env=env, print_system_info=True) 
    model.exploration_rate = 0.3
else:
    model = PPO.load(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}", env=env, print_system_info=True) 

model.learn(total_timesteps=fase2, log_interval=4,reset_num_timesteps=False, progress_bar=True)
model.save(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}")
env.close()
# Out:
# == CURRENT SYSTEM INFO ==
# - OS: Linux-6.14.0-36-generic-x86_64-with-glibc2.39 # 36~24.04.1-Ubuntu SMP PREEMPT_DYNAMIC Wed Oct 15 15:45:17 UTC 2
# - Python: 3.10.19
# - Stable-Baselines3: 2.7.0
# - PyTorch: 2.8.0+cu128
# - GPU Enabled: True
# - Numpy: 1.26.4
# - Cloudpickle: 3.1.1
# - Gymnasium: 1.2.1
#
# == SAVED MODEL SYSTEM INFO ==
# - OS: Linux-6.14.0-36-generic-x86_64-with-glibc2.39 # 36~24.04.1-Ubuntu SMP PREEMPT_DYNAMIC Wed Oct 15 15:45:17 UTC 2
# - Python: 3.10.19
# - Stable-Baselines3: 2.7.0
# - PyTorch: 2.8.0+cu128
# - GPU Enabled: True
# - Numpy: 1.26.4
# - Cloudpickle: 3.1.1
# - Gymnasium: 1.2.1
#
# Wrapping the env in a DummyVecEnv.
# Output()
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 4           |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.012494478 |
# |    clip_fraction        | 0.0756      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 62          |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | 0.0014      |
# |    value_loss           | 133         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 238         |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 8           |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.009158106 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 55          |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | 0.000749    |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 237         |
# |    ep_rew_mean          | 17.1        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 12          |
# |    time_elapsed         | 429         |
# |    total_timesteps      | 802816      |
# | train/                  |             |
# |    approx_kl            | 0.010395863 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 53.1        |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | 0.00342     |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 234         |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 16          |
# |    time_elapsed         | 573         |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.009242676 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 49.8        |
# |    n_updates            | 1990        |
# |    policy_gradient_loss | 0.00315     |
# |    value_loss           | 95.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 239          |
# |    ep_rew_mean          | 17.7         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 20           |
# |    time_elapsed         | 716          |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0071045733 |
# |    clip_fraction        | 0.0826       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 58.2         |
# |    n_updates            | 2030         |
# |    policy_gradient_loss | 0.00167      |
# |    value_loss           | 116          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 240         |
# |    ep_rew_mean          | 17.4        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 24          |
# |    time_elapsed         | 860         |
# |    total_timesteps      | 851968      |
# | train/                  |             |
# |    approx_kl            | 0.010201509 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 39.2        |
# |    n_updates            | 2070        |
# |    policy_gradient_loss | -0.000306   |
# |    value_loss           | 93.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 230         |
# |    ep_rew_mean          | 16.9        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 28          |
# |    time_elapsed         | 1005        |
# |    total_timesteps      | 868352      |
# | train/                  |             |
# |    approx_kl            | 0.011571505 |
# |    clip_fraction        | 0.0959      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 44          |
# |    n_updates            | 2110        |
# |    policy_gradient_loss | 0.00112     |
# |    value_loss           | 90.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 32          |
# |    time_elapsed         | 1149        |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.010521218 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 47.1        |
# |    n_updates            | 2150        |
# |    policy_gradient_loss | 0.00737     |
# |    value_loss           | 105         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 225         |
# |    ep_rew_mean          | 16.4        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 36          |
# |    time_elapsed         | 1294        |
# |    total_timesteps      | 901120      |
# | train/                  |             |
# |    approx_kl            | 0.007836578 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.984      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 40.1        |
# |    n_updates            | 2190        |
# |    policy_gradient_loss | 0.00213     |
# |    value_loss           | 84.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 221         |
# |    ep_rew_mean          | 16.4        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 40          |
# |    time_elapsed         | 1439        |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.009253466 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.942      |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 46.7        |
# |    n_updates            | 2230        |
# |    policy_gradient_loss | 0.00104     |
# |    value_loss           | 84.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 16.6        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 44          |
# |    time_elapsed         | 1584        |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.005044282 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.95       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 33.3        |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | 0.0012      |
# |    value_loss           | 83.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 227        |
# |    ep_rew_mean          | 16.2       |
# | time/                   |            |
# |    fps                  | 113        |
# |    iterations           | 48         |
# |    time_elapsed         | 1728       |
# |    total_timesteps      | 950272     |
# | train/                  |            |
# |    approx_kl            | 0.01838062 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.909     |
# |    explained_variance   | 0.966      |
# |    learning_rate        | 2e-05      |
# |    loss                 | 38.7       |
# |    n_updates            | 2310       |
# |    policy_gradient_loss | 0.00129    |
# |    value_loss           | 87.7       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 231          |
# |    ep_rew_mean          | 16.9         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 52           |
# |    time_elapsed         | 1873         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0057739643 |
# |    clip_fraction        | 0.0701       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.868       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 36.3         |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | -0.00117     |
# |    value_loss           | 91.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | 16.6        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 56          |
# |    time_elapsed         | 2018        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.016790748 |
# |    clip_fraction        | 0.0795      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 42.2        |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | 0.000452    |
# |    value_loss           | 81.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 237         |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 60          |
# |    time_elapsed         | 2163        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.011653738 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 45.4        |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | 0.00448     |
# |    value_loss           | 94.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | 17.5        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 64          |
# |    time_elapsed         | 2308        |
# |    total_timesteps      | 1015808     |
# | train/                  |             |
# |    approx_kl            | 0.009512264 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 38.6        |
# |    n_updates            | 2470        |
# |    policy_gradient_loss | 0.000946    |
# |    value_loss           | 85.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 231         |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 68          |
# |    time_elapsed         | 2453        |
# |    total_timesteps      | 1032192     |
# | train/                  |             |
# |    approx_kl            | 0.010894689 |
# |    clip_fraction        | 0.0954      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 2e-05       |
# |    loss                 | 35.1        |
# |    n_updates            | 2510        |
# |    policy_gradient_loss | 0.00195     |
# |    value_loss           | 84.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | 16.7        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 72          |
# |    time_elapsed         | 2598        |
# |    total_timesteps      | 1048576     |
# | train/                  |             |
# |    approx_kl            | 0.009447278 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 32.4        |
# |    n_updates            | 2550        |
# |    policy_gradient_loss | 0.000474    |
# |    value_loss           | 72.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 230         |
# |    ep_rew_mean          | 16.8        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 76          |
# |    time_elapsed         | 2743        |
# |    total_timesteps      | 1064960     |
# | train/                  |             |
# |    approx_kl            | 0.006013764 |
# |    clip_fraction        | 0.0759      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 37.6        |
# |    n_updates            | 2590        |
# |    policy_gradient_loss | 0.00165     |
# |    value_loss           | 79.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 16.6        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 80          |
# |    time_elapsed         | 2888        |
# |    total_timesteps      | 1081344     |
# | train/                  |             |
# |    approx_kl            | 0.006808803 |
# |    clip_fraction        | 0.0952      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.99       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 49.2        |
# |    n_updates            | 2630        |
# |    policy_gradient_loss | 0.00386     |
# |    value_loss           | 84.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 226         |
# |    ep_rew_mean          | 16.8        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 84          |
# |    time_elapsed         | 3033        |
# |    total_timesteps      | 1097728     |
# | train/                  |             |
# |    approx_kl            | 0.014629112 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.964      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 28.4        |
# |    n_updates            | 2670        |
# |    policy_gradient_loss | 0.00753     |
# |    value_loss           | 76.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 16.9         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 88           |
# |    time_elapsed         | 3178         |
# |    total_timesteps      | 1114112      |
# | train/                  |              |
# |    approx_kl            | 0.0069947736 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.893       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 34.7         |
# |    n_updates            | 2710         |
# |    policy_gradient_loss | 0.00416      |
# |    value_loss           | 75           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 223          |
# |    ep_rew_mean          | 16.5         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 92           |
# |    time_elapsed         | 3324         |
# |    total_timesteps      | 1130496      |
# | train/                  |              |
# |    approx_kl            | 0.0101881465 |
# |    clip_fraction        | 0.166        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.903       |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 24.9         |
# |    n_updates            | 2750         |
# |    policy_gradient_loss | 0.00495      |
# |    value_loss           | 58.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 234         |
# |    ep_rew_mean          | 17.1        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 96          |
# |    time_elapsed         | 3469        |
# |    total_timesteps      | 1146880     |
# | train/                  |             |
# |    approx_kl            | 0.005823395 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.875      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 29.7        |
# |    n_updates            | 2790        |
# |    policy_gradient_loss | 0.00209     |
# |    value_loss           | 71.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 235         |
# |    ep_rew_mean          | 17.1        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 100         |
# |    time_elapsed         | 3614        |
# |    total_timesteps      | 1163264     |
# | train/                  |             |
# |    approx_kl            | 0.008391064 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.904      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 31.2        |
# |    n_updates            | 2830        |
# |    policy_gradient_loss | 0.00144     |
# |    value_loss           | 71.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | 16.8        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 104         |
# |    time_elapsed         | 3759        |
# |    total_timesteps      | 1179648     |
# | train/                  |             |
# |    approx_kl            | 0.014818352 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.881      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 30.2        |
# |    n_updates            | 2870        |
# |    policy_gradient_loss | 0.00096     |
# |    value_loss           | 73.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 239          |
# |    ep_rew_mean          | 17.5         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 108          |
# |    time_elapsed         | 3903         |
# |    total_timesteps      | 1196032      |
# | train/                  |              |
# |    approx_kl            | 0.0050229905 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.885       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 23.7         |
# |    n_updates            | 2910         |
# |    policy_gradient_loss | 0.00541      |
# |    value_loss           | 50.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 245         |
# |    ep_rew_mean          | 17.6        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 112         |
# |    time_elapsed         | 4047        |
# |    total_timesteps      | 1212416     |
# | train/                  |             |
# |    approx_kl            | 0.005323746 |
# |    clip_fraction        | 0.0728      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.88       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 27.2        |
# |    n_updates            | 2950        |
# |    policy_gradient_loss | 0.00168     |
# |    value_loss           | 61.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 244          |
# |    ep_rew_mean          | 17.6         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 116          |
# |    time_elapsed         | 4192         |
# |    total_timesteps      | 1228800      |
# | train/                  |              |
# |    approx_kl            | 0.0044172658 |
# |    clip_fraction        | 0.0845       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.831       |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 29           |
# |    n_updates            | 2990         |
# |    policy_gradient_loss | 0.000397     |
# |    value_loss           | 54.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 255          |
# |    ep_rew_mean          | 18.2         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 120          |
# |    time_elapsed         | 4336         |
# |    total_timesteps      | 1245184      |
# | train/                  |              |
# |    approx_kl            | 0.0077707595 |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.73        |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 15.5         |
# |    n_updates            | 3030         |
# |    policy_gradient_loss | 0.000836     |
# |    value_loss           | 53.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 245         |
# |    ep_rew_mean          | 17.4        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 124         |
# |    time_elapsed         | 4481        |
# |    total_timesteps      | 1261568     |
# | train/                  |             |
# |    approx_kl            | 0.006722305 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.718      |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 24.3        |
# |    n_updates            | 3070        |
# |    policy_gradient_loss | 0.00313     |
# |    value_loss           | 46.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 235         |
# |    ep_rew_mean          | 17.1        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 128         |
# |    time_elapsed         | 4625        |
# |    total_timesteps      | 1277952     |
# | train/                  |             |
# |    approx_kl            | 0.008572418 |
# |    clip_fraction        | 0.0898      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.726      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 26.4        |
# |    n_updates            | 3110        |
# |    policy_gradient_loss | 0.00863     |
# |    value_loss           | 69          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 238          |
# |    ep_rew_mean          | 17.3         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 132          |
# |    time_elapsed         | 4770         |
# |    total_timesteps      | 1294336      |
# | train/                  |              |
# |    approx_kl            | 0.0085550705 |
# |    clip_fraction        | 0.0852       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 26.5         |
# |    n_updates            | 3150         |
# |    policy_gradient_loss | 0.00233      |
# |    value_loss           | 55.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 239         |
# |    ep_rew_mean          | 17.6        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 136         |
# |    time_elapsed         | 4915        |
# |    total_timesteps      | 1310720     |
# | train/                  |             |
# |    approx_kl            | 0.008949693 |
# |    clip_fraction        | 0.0677      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.671      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 31.7        |
# |    n_updates            | 3190        |
# |    policy_gradient_loss | 0.00147     |
# |    value_loss           | 60.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 140         |
# |    time_elapsed         | 5060        |
# |    total_timesteps      | 1327104     |
# | train/                  |             |
# |    approx_kl            | 0.010720134 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.703      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 27.5        |
# |    n_updates            | 3230        |
# |    policy_gradient_loss | 0.00502     |
# |    value_loss           | 50.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | 17.4        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 144         |
# |    time_elapsed         | 5205        |
# |    total_timesteps      | 1343488     |
# | train/                  |             |
# |    approx_kl            | 0.009396351 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.722      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 29.1        |
# |    n_updates            | 3270        |
# |    policy_gradient_loss | 0.00199     |
# |    value_loss           | 51.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 242          |
# |    ep_rew_mean          | 18           |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 148          |
# |    time_elapsed         | 5350         |
# |    total_timesteps      | 1359872      |
# | train/                  |              |
# |    approx_kl            | 0.0059943045 |
# |    clip_fraction        | 0.0664       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.821       |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 21.9         |
# |    n_updates            | 3310         |
# |    policy_gradient_loss | 4.59e-05     |
# |    value_loss           | 46.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 252         |
# |    ep_rew_mean          | 18.6        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 152         |
# |    time_elapsed         | 5495        |
# |    total_timesteps      | 1376256     |
# | train/                  |             |
# |    approx_kl            | 0.019480728 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 28.6        |
# |    n_updates            | 3350        |
# |    policy_gradient_loss | 0.00603     |
# |    value_loss           | 55.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 249        |
# |    ep_rew_mean          | 18.1       |
# | time/                   |            |
# |    fps                  | 113        |
# |    iterations           | 156        |
# |    time_elapsed         | 5640       |
# |    total_timesteps      | 1392640    |
# | train/                  |            |
# |    approx_kl            | 0.00935534 |
# |    clip_fraction        | 0.0962     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.978     |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 2e-05      |
# |    loss                 | 17.6       |
# |    n_updates            | 3390       |
# |    policy_gradient_loss | 0.000787   |
# |    value_loss           | 42.1       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 240          |
# |    ep_rew_mean          | 17.6         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 160          |
# |    time_elapsed         | 5784         |
# |    total_timesteps      | 1409024      |
# | train/                  |              |
# |    approx_kl            | 0.0059950203 |
# |    clip_fraction        | 0.0913       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 28           |
# |    n_updates            | 3430         |
# |    policy_gradient_loss | 0.00256      |
# |    value_loss           | 57.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 242         |
# |    ep_rew_mean          | 17.8        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 164         |
# |    time_elapsed         | 5928        |
# |    total_timesteps      | 1425408     |
# | train/                  |             |
# |    approx_kl            | 0.010797433 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 28          |
# |    n_updates            | 3470        |
# |    policy_gradient_loss | 0.00223     |
# |    value_loss           | 50.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 245         |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 168         |
# |    time_elapsed         | 6073        |
# |    total_timesteps      | 1441792     |
# | train/                  |             |
# |    approx_kl            | 0.009033516 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.948      |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 18.4        |
# |    n_updates            | 3510        |
# |    policy_gradient_loss | 0.00774     |
# |    value_loss           | 46.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 248          |
# |    ep_rew_mean          | 17.4         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 172          |
# |    time_elapsed         | 6217         |
# |    total_timesteps      | 1458176      |
# | train/                  |              |
# |    approx_kl            | 0.0061492585 |
# |    clip_fraction        | 0.0979       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.966       |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 17           |
# |    n_updates            | 3550         |
# |    policy_gradient_loss | -0.000195    |
# |    value_loss           | 44.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 258         |
# |    ep_rew_mean          | 18.2        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 176         |
# |    time_elapsed         | 6362        |
# |    total_timesteps      | 1474560     |
# | train/                  |             |
# |    approx_kl            | 0.013098136 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 26.3        |
# |    n_updates            | 3590        |
# |    policy_gradient_loss | 0.00144     |
# |    value_loss           | 47.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 263         |
# |    ep_rew_mean          | 18.3        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 180         |
# |    time_elapsed         | 6506        |
# |    total_timesteps      | 1490944     |
# | train/                  |             |
# |    approx_kl            | 0.008088844 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 18.4        |
# |    n_updates            | 3630        |
# |    policy_gradient_loss | 0.00464     |
# |    value_loss           | 48.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 258          |
# |    ep_rew_mean          | 17.8         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 184          |
# |    time_elapsed         | 6650         |
# |    total_timesteps      | 1507328      |
# | train/                  |              |
# |    approx_kl            | 0.0070511224 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 21.4         |
# |    n_updates            | 3670         |
# |    policy_gradient_loss | 0.00312      |
# |    value_loss           | 47           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 257          |
# |    ep_rew_mean          | 17.7         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 188          |
# |    time_elapsed         | 6793         |
# |    total_timesteps      | 1523712      |
# | train/                  |              |
# |    approx_kl            | 0.0061860397 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 2e-05        |
# |    loss                 | 26           |
# |    n_updates            | 3710         |
# |    policy_gradient_loss | 0.00538      |
# |    value_loss           | 42.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 255         |
# |    ep_rew_mean          | 17.7        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 192         |
# |    time_elapsed         | 6937        |
# |    total_timesteps      | 1540096     |
# | train/                  |             |
# |    approx_kl            | 0.006637968 |
# |    clip_fraction        | 0.0907      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 22.7        |
# |    n_updates            | 3750        |
# |    policy_gradient_loss | 0.000706    |
# |    value_loss           | 44.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 259         |
# |    ep_rew_mean          | 18.1        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 196         |
# |    time_elapsed         | 7082        |
# |    total_timesteps      | 1556480     |
# | train/                  |             |
# |    approx_kl            | 0.008392308 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 22.3        |
# |    n_updates            | 3790        |
# |    policy_gradient_loss | 0.00267     |
# |    value_loss           | 52.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 253         |
# |    ep_rew_mean          | 17.9        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 200         |
# |    time_elapsed         | 7225        |
# |    total_timesteps      | 1572864     |
# | train/                  |             |
# |    approx_kl            | 0.013352528 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 16.7        |
# |    n_updates            | 3830        |
# |    policy_gradient_loss | 0.00262     |
# |    value_loss           | 41.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 258          |
# |    ep_rew_mean          | 18.1         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 204          |
# |    time_elapsed         | 7369         |
# |    total_timesteps      | 1589248      |
# | train/                  |              |
# |    approx_kl            | 0.0073198075 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 17           |
# |    n_updates            | 3870         |
# |    policy_gradient_loss | 0.0026       |
# |    value_loss           | 34.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 260         |
# |    ep_rew_mean          | 18          |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 208         |
# |    time_elapsed         | 7513        |
# |    total_timesteps      | 1605632     |
# | train/                  |             |
# |    approx_kl            | 0.005483841 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 18.3        |
# |    n_updates            | 3910        |
# |    policy_gradient_loss | 0.00281     |
# |    value_loss           | 36.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 265         |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 212         |
# |    time_elapsed         | 7657        |
# |    total_timesteps      | 1622016     |
# | train/                  |             |
# |    approx_kl            | 0.008732004 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 20.6        |
# |    n_updates            | 3950        |
# |    policy_gradient_loss | 0.00171     |
# |    value_loss           | 45.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 266         |
# |    ep_rew_mean          | 18.6        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 216         |
# |    time_elapsed         | 7802        |
# ...
# |    ep_len_mean          | 267         |
# |    ep_rew_mean          | 19.4        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 236         |
# |    time_elapsed         | 8524        |
# |    total_timesteps      | 1720320     |
# | train/                  |             |
# |    approx_kl            | 0.012413592 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 18.6        |
# |    n_updates            | 4190        |
# |    policy_gradient_loss | 0.00599     |
# |    value_loss           | 51.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 263        |
# |    ep_rew_mean          | 19.1       |
# | time/                   |            |
# |    fps                  | 113        |
# |    iterations           | 240        |
# |    time_elapsed         | 8669       |
# |    total_timesteps      | 1736704    |
# | train/                  |            |
# |    approx_kl            | 0.01048579 |
# |    clip_fraction        | 0.0986     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.889     |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 2e-05      |
# |    loss                 | 21.2       |
# |    n_updates            | 4230       |
# |    policy_gradient_loss | 0.00187    |
# |    value_loss           | 51.4       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 261          |
# |    ep_rew_mean          | 19.2         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 244          |
# |    time_elapsed         | 8813         |
# |    total_timesteps      | 1753088      |
# | train/                  |              |
# |    approx_kl            | 0.0070911655 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.953       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 27.4         |
# |    n_updates            | 4270         |
# |    policy_gradient_loss | 0.00266      |
# |    value_loss           | 56.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 262         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 248         |
# |    time_elapsed         | 8958        |
# |    total_timesteps      | 1769472     |
# | train/                  |             |
# |    approx_kl            | 0.009644728 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.897      |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 19.3        |
# |    n_updates            | 4310        |
# |    policy_gradient_loss | 0.00227     |
# |    value_loss           | 59.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 267          |
# |    ep_rew_mean          | 19.4         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 252          |
# |    time_elapsed         | 9102         |
# |    total_timesteps      | 1785856      |
# | train/                  |              |
# |    approx_kl            | 0.0062056594 |
# |    clip_fraction        | 0.0946       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.91        |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 2e-05        |
# |    loss                 | 20.8         |
# |    n_updates            | 4350         |
# |    policy_gradient_loss | -2.85e-05    |
# |    value_loss           | 43.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 270         |
# |    ep_rew_mean          | 19.4        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 256         |
# |    time_elapsed         | 9247        |
# |    total_timesteps      | 1802240     |
# | train/                  |             |
# |    approx_kl            | 0.008100211 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.885      |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 20.6        |
# |    n_updates            | 4390        |
# |    policy_gradient_loss | 0.00242     |
# |    value_loss           | 50.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 274         |
# |    ep_rew_mean          | 19.6        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 260         |
# |    time_elapsed         | 9392        |
# |    total_timesteps      | 1818624     |
# | train/                  |             |
# |    approx_kl            | 0.011652258 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 22.7        |
# |    n_updates            | 4430        |
# |    policy_gradient_loss | 0.0033      |
# |    value_loss           | 44.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 275        |
# |    ep_rew_mean          | 19.8       |
# | time/                   |            |
# |    fps                  | 113        |
# |    iterations           | 264        |
# |    time_elapsed         | 9536       |
# |    total_timesteps      | 1835008    |
# | train/                  |            |
# |    approx_kl            | 0.00794011 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.979     |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 2e-05      |
# |    loss                 | 22         |
# |    n_updates            | 4470       |
# |    policy_gradient_loss | 0.00194    |
# |    value_loss           | 53.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 270         |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 268         |
# |    time_elapsed         | 9680        |
# |    total_timesteps      | 1851392     |
# | train/                  |             |
# |    approx_kl            | 0.009867737 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 24.9        |
# |    n_updates            | 4510        |
# |    policy_gradient_loss | 0.00254     |
# |    value_loss           | 50          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 261          |
# |    ep_rew_mean          | 19           |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 272          |
# |    time_elapsed         | 9824         |
# |    total_timesteps      | 1867776      |
# | train/                  |              |
# |    approx_kl            | 0.0069951117 |
# |    clip_fraction        | 0.0998       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.911       |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 17.2         |
# |    n_updates            | 4550         |
# |    policy_gradient_loss | 0.00217      |
# |    value_loss           | 38.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 260         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 276         |
# |    time_elapsed         | 9968        |
# |    total_timesteps      | 1884160     |
# | train/                  |             |
# |    approx_kl            | 0.008866837 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.928      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 20.7        |
# |    n_updates            | 4590        |
# |    policy_gradient_loss | 0.00315     |
# |    value_loss           | 43.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 265         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 280         |
# |    time_elapsed         | 10111       |
# |    total_timesteps      | 1900544     |
# | train/                  |             |
# |    approx_kl            | 0.009635087 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 20.7        |
# |    n_updates            | 4630        |
# |    policy_gradient_loss | 0.00255     |
# |    value_loss           | 43.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 269         |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 284         |
# |    time_elapsed         | 10255       |
# |    total_timesteps      | 1916928     |
# | train/                  |             |
# |    approx_kl            | 0.010156775 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 22          |
# |    n_updates            | 4670        |
# |    policy_gradient_loss | 0.000136    |
# |    value_loss           | 48.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 276          |
# |    ep_rew_mean          | 18.9         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 288          |
# |    time_elapsed         | 10398        |
# |    total_timesteps      | 1933312      |
# | train/                  |              |
# |    approx_kl            | 0.0087788645 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.928       |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 16           |
# |    n_updates            | 4710         |
# |    policy_gradient_loss | 0.000995     |
# |    value_loss           | 35.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 272         |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 292         |
# |    time_elapsed         | 10541       |
# |    total_timesteps      | 1949696     |
# | train/                  |             |
# |    approx_kl            | 0.007623713 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.948      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 23.8        |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | 0.00105     |
# |    value_loss           | 42.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 264          |
# |    ep_rew_mean          | 19           |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 296          |
# |    time_elapsed         | 10685        |
# |    total_timesteps      | 1966080      |
# | train/                  |              |
# |    approx_kl            | 0.0068105087 |
# |    clip_fraction        | 0.0787       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.994       |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 19.9         |
# |    n_updates            | 4790         |
# |    policy_gradient_loss | 0.00203      |
# |    value_loss           | 46.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 259         |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 300         |
# |    time_elapsed         | 10828       |
# |    total_timesteps      | 1982464     |
# | train/                  |             |
# |    approx_kl            | 0.009721551 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.91       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 15          |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | 0.00301     |
# |    value_loss           | 37.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 268         |
# |    ep_rew_mean          | 18.7        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 304         |
# |    time_elapsed         | 10972       |
# |    total_timesteps      | 1998848     |
# | train/                  |             |
# |    approx_kl            | 0.007415334 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.894      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 16.9        |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | 0.00303     |
# |    value_loss           | 40.7        |
# -----------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
env = make_env(game = "tetris_gymnasium/Tetris", render_mode="rgb_array", obs_type="RGB", increase_height_penalty = 1.0, increase_holes_penalty = 1.0, dif_heigh_penalty = 0.2, line1=0.5, line2=3, line3=6, line4=15, gameover=50, trunc=10, fase=3)
if Model == "DQN":
    model = DQN.load(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}", env=env, print_system_info=True) 
    model.exploration_rate = 0.3
else:
    model = PPO.load(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}", env=env, print_system_info=True) 

model.learn(total_timesteps=fase3, log_interval=4, reset_num_timesteps=False, progress_bar=True)
model.save(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}")
env.close()
# Out:
# == CURRENT SYSTEM INFO ==
# - OS: Linux-6.14.0-36-generic-x86_64-with-glibc2.39 # 36~24.04.1-Ubuntu SMP PREEMPT_DYNAMIC Wed Oct 15 15:45:17 UTC 2
# - Python: 3.10.19
# - Stable-Baselines3: 2.7.0
# - PyTorch: 2.8.0+cu128
# - GPU Enabled: True
# - Numpy: 1.26.4
# - Cloudpickle: 3.1.1
# - Gymnasium: 1.2.1
#
# == SAVED MODEL SYSTEM INFO ==
# - OS: Linux-6.14.0-36-generic-x86_64-with-glibc2.39 # 36~24.04.1-Ubuntu SMP PREEMPT_DYNAMIC Wed Oct 15 15:45:17 UTC 2
# - Python: 3.10.19
# - Stable-Baselines3: 2.7.0
# - PyTorch: 2.8.0+cu128
# - GPU Enabled: True
# - Numpy: 1.26.4
# - Cloudpickle: 3.1.1
# - Gymnasium: 1.2.1
#
# Wrapping the env in a DummyVecEnv.
# Output()
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 258          |
# |    ep_rew_mean          | 18           |
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 4            |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 2023424      |
# | train/                  |              |
# |    approx_kl            | 0.0078522805 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.964       |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 7.48         |
# |    n_updates            | 4930         |
# |    policy_gradient_loss | 0.000838     |
# |    value_loss           | 18.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | 17.4        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 8           |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 2039808     |
# | train/                  |             |
# |    approx_kl            | 0.005130017 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.959      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 2e-05       |
# |    loss                 | 6.26        |
# |    n_updates            | 4970        |
# |    policy_gradient_loss | 0.000499    |
# |    value_loss           | 16.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 216         |
# |    ep_rew_mean          | 17.1        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 12          |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 2056192     |
# | train/                  |             |
# |    approx_kl            | 0.011346489 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 14.1        |
# |    n_updates            | 5010        |
# |    policy_gradient_loss | 0.00243     |
# |    value_loss           | 39.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 16.9        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 16          |
# |    time_elapsed         | 565         |
# |    total_timesteps      | 2072576     |
# | train/                  |             |
# |    approx_kl            | 0.007905677 |
# |    clip_fraction        | 0.0887      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 12.5        |
# |    n_updates            | 5050        |
# |    policy_gradient_loss | 6.94e-06    |
# |    value_loss           | 19.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 205          |
# |    ep_rew_mean          | 16.7         |
# | time/                   |              |
# |    fps                  | 115          |
# |    iterations           | 20           |
# |    time_elapsed         | 708          |
# |    total_timesteps      | 2088960      |
# | train/                  |              |
# |    approx_kl            | 0.0065963827 |
# |    clip_fraction        | 0.0605       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 7.33         |
# |    n_updates            | 5090         |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 17.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 17.6        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 24          |
# |    time_elapsed         | 852         |
# |    total_timesteps      | 2105344     |
# | train/                  |             |
# |    approx_kl            | 0.005109918 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 6.42        |
# |    n_updates            | 5130        |
# |    policy_gradient_loss | -0.00307    |
# |    value_loss           | 16.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 244         |
# |    ep_rew_mean          | 18.1        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 28          |
# |    time_elapsed         | 995         |
# |    total_timesteps      | 2121728     |
# | train/                  |             |
# |    approx_kl            | 0.004258289 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 8.12        |
# |    n_updates            | 5170        |
# |    policy_gradient_loss | 0.00158     |
# |    value_loss           | 14.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 251         |
# |    ep_rew_mean          | 17.9        |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 32          |
# |    time_elapsed         | 1138        |
# |    total_timesteps      | 2138112     |
# | train/                  |             |
# |    approx_kl            | 0.007944937 |
# |    clip_fraction        | 0.0806      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.972      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 2e-05       |
# |    loss                 | 5.98        |
# |    n_updates            | 5210        |
# |    policy_gradient_loss | 0.00044     |
# |    value_loss           | 12.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 251        |
# |    ep_rew_mean          | 17.8       |
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 36         |
# |    time_elapsed         | 1281       |
# |    total_timesteps      | 2154496    |
# | train/                  |            |
# |    approx_kl            | 0.00720087 |
# |    clip_fraction        | 0.071      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 2e-05      |
# |    loss                 | 7.45       |
# |    n_updates            | 5250       |
# |    policy_gradient_loss | 0.00127    |
# |    value_loss           | 13.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 252         |
# |    ep_rew_mean          | 17.7        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 40          |
# |    time_elapsed         | 1424        |
# |    total_timesteps      | 2170880     |
# | train/                  |             |
# |    approx_kl            | 0.009454323 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 8.62        |
# |    n_updates            | 5290        |
# |    policy_gradient_loss | 0.00264     |
# |    value_loss           | 15.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 256        |
# |    ep_rew_mean          | 17.7       |
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 44         |
# |    time_elapsed         | 1568       |
# |    total_timesteps      | 2187264    |
# | train/                  |            |
# |    approx_kl            | 0.00496503 |
# |    clip_fraction        | 0.0437     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.946     |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 2e-05      |
# |    loss                 | 4.61       |
# |    n_updates            | 5330       |
# |    policy_gradient_loss | -0.00144   |
# |    value_loss           | 11.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 266         |
# |    ep_rew_mean          | 18.3        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 48          |
# |    time_elapsed         | 1712        |
# |    total_timesteps      | 2203648     |
# | train/                  |             |
# |    approx_kl            | 0.007962208 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.897      |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 7.1         |
# |    n_updates            | 5370        |
# |    policy_gradient_loss | -0.000982   |
# |    value_loss           | 17.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 261          |
# |    ep_rew_mean          | 18.2         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 52           |
# |    time_elapsed         | 1855         |
# |    total_timesteps      | 2220032      |
# | train/                  |              |
# |    approx_kl            | 0.0051021418 |
# |    clip_fraction        | 0.088        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.837       |
# |    explained_variance   | 0.945        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 5.01         |
# |    n_updates            | 5410         |
# |    policy_gradient_loss | 0.00573      |
# |    value_loss           | 11.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 264         |
# |    ep_rew_mean          | 18.3        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 56          |
# |    time_elapsed         | 1999        |
# |    total_timesteps      | 2236416     |
# | train/                  |             |
# |    approx_kl            | 0.006139676 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.914      |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 6.6         |
# |    n_updates            | 5450        |
# |    policy_gradient_loss | 0.00186     |
# |    value_loss           | 13.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 260          |
# |    ep_rew_mean          | 17.8         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 60           |
# |    time_elapsed         | 2143         |
# |    total_timesteps      | 2252800      |
# | train/                  |              |
# |    approx_kl            | 0.0070452476 |
# |    clip_fraction        | 0.0859       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.897       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 3.65         |
# |    n_updates            | 5490         |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 11           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 260         |
# |    ep_rew_mean          | 17.6        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 64          |
# |    time_elapsed         | 2286        |
# |    total_timesteps      | 2269184     |
# | train/                  |             |
# |    approx_kl            | 0.007845975 |
# |    clip_fraction        | 0.076       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 4.78        |
# |    n_updates            | 5530        |
# |    policy_gradient_loss | 0.00205     |
# |    value_loss           | 10.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 264          |
# |    ep_rew_mean          | 18.4         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 68           |
# |    time_elapsed         | 2429         |
# |    total_timesteps      | 2285568      |
# | train/                  |              |
# |    approx_kl            | 0.0069490555 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 4.96         |
# |    n_updates            | 5570         |
# |    policy_gradient_loss | 0.00053      |
# |    value_loss           | 12.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 263        |
# |    ep_rew_mean          | 18.7       |
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 72         |
# |    time_elapsed         | 2573       |
# |    total_timesteps      | 2301952    |
# | train/                  |            |
# |    approx_kl            | 0.01839275 |
# |    clip_fraction        | 0.0767     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 2e-05      |
# |    loss                 | 6.92       |
# |    n_updates            | 5610       |
# |    policy_gradient_loss | 0.00111    |
# |    value_loss           | 12.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 257         |
# |    ep_rew_mean          | 18.2        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 76          |
# |    time_elapsed         | 2716        |
# |    total_timesteps      | 2318336     |
# | train/                  |             |
# |    approx_kl            | 0.011913536 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 7.39        |
# |    n_updates            | 5650        |
# |    policy_gradient_loss | -0.00015    |
# |    value_loss           | 16.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 245        |
# |    ep_rew_mean          | 17.4       |
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 80         |
# |    time_elapsed         | 2860       |
# |    total_timesteps      | 2334720    |
# | train/                  |            |
# |    approx_kl            | 0.02013668 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 2e-05      |
# |    loss                 | 4.19       |
# |    n_updates            | 5690       |
# |    policy_gradient_loss | -0.00139   |
# |    value_loss           | 10.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | 18          |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 84          |
# |    time_elapsed         | 3004        |
# |    total_timesteps      | 2351104     |
# | train/                  |             |
# |    approx_kl            | 0.006764101 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 8.8         |
# |    n_updates            | 5730        |
# |    policy_gradient_loss | 0.00056     |
# |    value_loss           | 14.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 255          |
# |    ep_rew_mean          | 18.4         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 88           |
# |    time_elapsed         | 3147         |
# |    total_timesteps      | 2367488      |
# | train/                  |              |
# |    approx_kl            | 0.0066644913 |
# |    clip_fraction        | 0.0663       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.945        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 6.14         |
# |    n_updates            | 5770         |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 14.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 258          |
# |    ep_rew_mean          | 18.3         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 92           |
# |    time_elapsed         | 3289         |
# |    total_timesteps      | 2383872      |
# | train/                  |              |
# |    approx_kl            | 0.0047233244 |
# |    clip_fraction        | 0.072        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 6.67         |
# |    n_updates            | 5810         |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 14.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 258         |
# |    ep_rew_mean          | 18.4        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 96          |
# |    time_elapsed         | 3432        |
# |    total_timesteps      | 2400256     |
# | train/                  |             |
# |    approx_kl            | 0.009227003 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 7.54        |
# |    n_updates            | 5850        |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 12.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 262         |
# |    ep_rew_mean          | 18.6        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 100         |
# |    time_elapsed         | 3575        |
# |    total_timesteps      | 2416640     |
# | train/                  |             |
# |    approx_kl            | 0.010048064 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.878      |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 2e-05       |
# |    loss                 | 4.13        |
# |    n_updates            | 5890        |
# |    policy_gradient_loss | 0.000504    |
# |    value_loss           | 13.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 263          |
# |    ep_rew_mean          | 19           |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 104          |
# |    time_elapsed         | 3719         |
# |    total_timesteps      | 2433024      |
# | train/                  |              |
# |    approx_kl            | 0.0055419104 |
# |    clip_fraction        | 0.075        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.921       |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 2e-05        |
# |    loss                 | 4.87         |
# |    n_updates            | 5930         |
# |    policy_gradient_loss | 0.000895     |
# |    value_loss           | 10.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 252          |
# |    ep_rew_mean          | 17.9         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 108          |
# |    time_elapsed         | 3863         |
# |    total_timesteps      | 2449408      |
# | train/                  |              |
# |    approx_kl            | 0.0054697953 |
# |    clip_fraction        | 0.0945       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.898       |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 4.78         |
# |    n_updates            | 5970         |
# |    policy_gradient_loss | 0.000532     |
# |    value_loss           | 11.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 253          |
# |    ep_rew_mean          | 17.9         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 112          |
# |    time_elapsed         | 4007         |
# |    total_timesteps      | 2465792      |
# | train/                  |              |
# |    approx_kl            | 0.0064668367 |
# |    clip_fraction        | 0.0874       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.918       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 5.61         |
# |    n_updates            | 6010         |
# |    policy_gradient_loss | 0.00119      |
# |    value_loss           | 11           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 246          |
# |    ep_rew_mean          | 17.6         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 116          |
# |    time_elapsed         | 4151         |
# |    total_timesteps      | 2482176      |
# | train/                  |              |
# |    approx_kl            | 0.0052426625 |
# |    clip_fraction        | 0.0684       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.84        |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 4.2          |
# |    n_updates            | 6050         |
# |    policy_gradient_loss | -0.000351    |
# |    value_loss           | 9.69         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 244          |
# |    ep_rew_mean          | 17           |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 120          |
# |    time_elapsed         | 4295         |
# |    total_timesteps      | 2498560      |
# | train/                  |              |
# |    approx_kl            | 0.0064954413 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.903       |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 5.05         |
# |    n_updates            | 6090         |
# |    policy_gradient_loss | 0.00335      |
# |    value_loss           | 13.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 241         |
# |    ep_rew_mean          | 16.9        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 124         |
# |    time_elapsed         | 4438        |
# |    total_timesteps      | 2514944     |
# | train/                  |             |
# |    approx_kl            | 0.009730339 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 3.49        |
# |    n_updates            | 6130        |
# |    policy_gradient_loss | 0.000553    |
# |    value_loss           | 9.95        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 255         |
# |    ep_rew_mean          | 18          |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 128         |
# |    time_elapsed         | 4582        |
# |    total_timesteps      | 2531328     |
# | train/                  |             |
# |    approx_kl            | 0.006536642 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.823      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 5.14        |
# |    n_updates            | 6170        |
# |    policy_gradient_loss | 5.39e-05    |
# |    value_loss           | 11          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 263         |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 132         |
# |    time_elapsed         | 4726        |
# |    total_timesteps      | 2547712     |
# | train/                  |             |
# |    approx_kl            | 0.007681789 |
# |    clip_fraction        | 0.0679      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.875      |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 3.95        |
# |    n_updates            | 6210        |
# |    policy_gradient_loss | 0.00261     |
# |    value_loss           | 11          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 265          |
# |    ep_rew_mean          | 18.9         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 136          |
# |    time_elapsed         | 4870         |
# |    total_timesteps      | 2564096      |
# | train/                  |              |
# |    approx_kl            | 0.0061111175 |
# |    clip_fraction        | 0.0695       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.927       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 4.02         |
# |    n_updates            | 6250         |
# |    policy_gradient_loss | 0.000167     |
# |    value_loss           | 10.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 259          |
# |    ep_rew_mean          | 18.1         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 140          |
# |    time_elapsed         | 5013         |
# |    total_timesteps      | 2580480      |
# | train/                  |              |
# |    approx_kl            | 0.0056608915 |
# |    clip_fraction        | 0.0938       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.994       |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 4.58         |
# |    n_updates            | 6290         |
# |    policy_gradient_loss | 0.000931     |
# |    value_loss           | 10.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 260          |
# |    ep_rew_mean          | 18.4         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 144          |
# |    time_elapsed         | 5157         |
# |    total_timesteps      | 2596864      |
# | train/                  |              |
# |    approx_kl            | 0.0035687827 |
# |    clip_fraction        | 0.073        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.872       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 3.69         |
# |    n_updates            | 6330         |
# |    policy_gradient_loss | 0.00337      |
# |    value_loss           | 10.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 253         |
# |    ep_rew_mean          | 18.1        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 148         |
# |    time_elapsed         | 5301        |
# |    total_timesteps      | 2613248     |
# | train/                  |             |
# |    approx_kl            | 0.008873395 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 4.87        |
# |    n_updates            | 6370        |
# |    policy_gradient_loss | -0.00172    |
# |    value_loss           | 10.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 248         |
# |    ep_rew_mean          | 17.7        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 152         |
# |    time_elapsed         | 5445        |
# |    total_timesteps      | 2629632     |
# | train/                  |             |
# |    approx_kl            | 0.010079317 |
# |    clip_fraction        | 0.0794      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.955      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 4.7         |
# |    n_updates            | 6410        |
# |    policy_gradient_loss | 0.00235     |
# |    value_loss           | 9.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | 17.5        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 156         |
# |    time_elapsed         | 5588        |
# |    total_timesteps      | 2646016     |
# | train/                  |             |
# |    approx_kl            | 0.010959288 |
# |    clip_fraction        | 0.0798      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 3.75        |
# |    n_updates            | 6450        |
# |    policy_gradient_loss | -0.000106   |
# |    value_loss           | 12.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | 16.9         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 160          |
# |    time_elapsed         | 5732         |
# |    total_timesteps      | 2662400      |
# | train/                  |              |
# |    approx_kl            | 0.0062731616 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.962       |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 4.9          |
# |    n_updates            | 6490         |
# |    policy_gradient_loss | -0.000415    |
# |    value_loss           | 13.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 252          |
# |    ep_rew_mean          | 17.4         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 164          |
# |    time_elapsed         | 5876         |
# |    total_timesteps      | 2678784      |
# | train/                  |              |
# |    approx_kl            | 0.0069092824 |
# |    clip_fraction        | 0.0873       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.958       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 6.7          |
# |    n_updates            | 6530         |
# |    policy_gradient_loss | -0.000992    |
# |    value_loss           | 10.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 248          |
# |    ep_rew_mean          | 17.5         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 168          |
# |    time_elapsed         | 6021         |
# |    total_timesteps      | 2695168      |
# | train/                  |              |
# |    approx_kl            | 0.0069270907 |
# |    clip_fraction        | 0.067        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.976       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 3.86         |
# |    n_updates            | 6570         |
# |    policy_gradient_loss | 0.00261      |
# |    value_loss           | 10.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 250          |
# |    ep_rew_mean          | 17.4         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 172          |
# |    time_elapsed         | 6165         |
# |    total_timesteps      | 2711552      |
# | train/                  |              |
# |    approx_kl            | 0.0058247275 |
# |    clip_fraction        | 0.0641       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.921       |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 3.37         |
# |    n_updates            | 6610         |
# |    policy_gradient_loss | 0.00625      |
# |    value_loss           | 9.59         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 244         |
# |    ep_rew_mean          | 16.9        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 176         |
# |    time_elapsed         | 6309        |
# |    total_timesteps      | 2727936     |
# | train/                  |             |
# |    approx_kl            | 0.008247351 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.941      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 6.24        |
# |    n_updates            | 6650        |
# |    policy_gradient_loss | 0.00229     |
# |    value_loss           | 10.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 249         |
# |    ep_rew_mean          | 17.7        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 180         |
# |    time_elapsed         | 6453        |
# |    total_timesteps      | 2744320     |
# | train/                  |             |
# |    approx_kl            | 0.006074207 |
# |    clip_fraction        | 0.0907      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 4.95        |
# |    n_updates            | 6690        |
# |    policy_gradient_loss | 0.00213     |
# |    value_loss           | 12          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 255         |
# |    ep_rew_mean          | 18.1        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 184         |
# |    time_elapsed         | 6597        |
# |    total_timesteps      | 2760704     |
# | train/                  |             |
# |    approx_kl            | 0.011177458 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 3.43        |
# |    n_updates            | 6730        |
# |    policy_gradient_loss | -0.00125    |
# |    value_loss           | 10.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | 18.3         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 188          |
# |    time_elapsed         | 6742         |
# |    total_timesteps      | 2777088      |
# | train/                  |              |
# |    approx_kl            | 0.0052388264 |
# |    clip_fraction        | 0.0569       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.901       |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 4.64         |
# |    n_updates            | 6770         |
# |    policy_gradient_loss | 0.000249     |
# |    value_loss           | 8.94         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | 18          |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 192         |
# |    time_elapsed         | 6886        |
# |    total_timesteps      | 2793472     |
# | train/                  |             |
# |    approx_kl            | 0.005199798 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.851      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 3.27        |
# |    n_updates            | 6810        |
# |    policy_gradient_loss | 0.00109     |
# |    value_loss           | 9.05        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 255          |
# |    ep_rew_mean          | 18.1         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 196          |
# |    time_elapsed         | 7030         |
# |    total_timesteps      | 2809856      |
# | train/                  |              |
# |    approx_kl            | 0.0048714527 |
# |    clip_fraction        | 0.052        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.827       |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 3.02         |
# |    n_updates            | 6850         |
# |    policy_gradient_loss | 0.000908     |
# |    value_loss           | 7.8          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 257          |
# |    ep_rew_mean          | 18           |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 200          |
# |    time_elapsed         | 7174         |
# |    total_timesteps      | 2826240      |
# | train/                  |              |
# |    approx_kl            | 0.0044721686 |
# |    clip_fraction        | 0.0648       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.794       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 3.29         |
# |    n_updates            | 6890         |
# |    policy_gradient_loss | -0.000492    |
# |    value_loss           | 8.56         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 254          |
# |    ep_rew_mean          | 17.8         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 204          |
# |    time_elapsed         | 7318         |
# |    total_timesteps      | 2842624      |
# | train/                  |              |
# |    approx_kl            | 0.0041584927 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.808       |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 3.25         |
# |    n_updates            | 6930         |
# |    policy_gradient_loss | 0.002        |
# |    value_loss           | 7.83         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 253        |
# |    ep_rew_mean          | 17.9       |
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 208        |
# |    time_elapsed         | 7462       |
# |    total_timesteps      | 2859008    |
# | train/                  |            |
# |    approx_kl            | 0.00836305 |
# |    clip_fraction        | 0.0759     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.863     |
# |    explained_variance   | 0.966      |
# |    learning_rate        | 2e-05      |
# |    loss                 | 5.15       |
# |    n_updates            | 6970       |
# |    policy_gradient_loss | 0.00209    |
# |    value_loss           | 9.89       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 261         |
# |    ep_rew_mean          | 18.4        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 212         |
# |    time_elapsed         | 7606        |
# |    total_timesteps      | 2875392     |
# | train/                  |             |
# |    approx_kl            | 0.007698931 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 4.33        |
# |    n_updates            | 7010        |
# |    policy_gradient_loss | 0.0033      |
# |    value_loss           | 10.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 259         |
# |    ep_rew_mean          | 17.9        |
# | time/                   |             |
# ...
# |    iterations           | 224          |
# |    time_elapsed         | 8039         |
# |    total_timesteps      | 2924544      |
# | train/                  |              |
# |    approx_kl            | 0.0081060985 |
# |    clip_fraction        | 0.0867       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.922       |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 5.36         |
# |    n_updates            | 7130         |
# |    policy_gradient_loss | 0.000946     |
# |    value_loss           | 8.29         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 257          |
# |    ep_rew_mean          | 18           |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 228          |
# |    time_elapsed         | 8183         |
# |    total_timesteps      | 2940928      |
# | train/                  |              |
# |    approx_kl            | 0.0029794541 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.962       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 4.34         |
# |    n_updates            | 7170         |
# |    policy_gradient_loss | 0.000901     |
# |    value_loss           | 9.99         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 266         |
# |    ep_rew_mean          | 18.5        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 232         |
# |    time_elapsed         | 8327        |
# |    total_timesteps      | 2957312     |
# | train/                  |             |
# |    approx_kl            | 0.010036783 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.964      |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 4.66        |
# |    n_updates            | 7210        |
# |    policy_gradient_loss | -0.00195    |
# |    value_loss           | 10.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 267         |
# |    ep_rew_mean          | 18.6        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 236         |
# |    time_elapsed         | 8471        |
# |    total_timesteps      | 2973696     |
# | train/                  |             |
# |    approx_kl            | 0.008525481 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 5.15        |
# |    n_updates            | 7250        |
# |    policy_gradient_loss | 0.0011      |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 264         |
# |    ep_rew_mean          | 18.4        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 240         |
# |    time_elapsed         | 8616        |
# |    total_timesteps      | 2990080     |
# | train/                  |             |
# |    approx_kl            | 0.009855168 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 3.42        |
# |    n_updates            | 7290        |
# |    policy_gradient_loss | 0.000451    |
# |    value_loss           | 8.78        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 256        |
# |    ep_rew_mean          | 18         |
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 244        |
# |    time_elapsed         | 8759       |
# |    total_timesteps      | 3006464    |
# | train/                  |            |
# |    approx_kl            | 0.00522884 |
# |    clip_fraction        | 0.0454     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 2e-05      |
# |    loss                 | 4.46       |
# |    n_updates            | 7330       |
# |    policy_gradient_loss | 0.00106    |
# |    value_loss           | 10.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 255         |
# |    ep_rew_mean          | 17.7        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 248         |
# |    time_elapsed         | 8903        |
# |    total_timesteps      | 3022848     |
# | train/                  |             |
# |    approx_kl            | 0.007777637 |
# |    clip_fraction        | 0.0679      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 2e-05       |
# |    loss                 | 4.06        |
# |    n_updates            | 7370        |
# |    policy_gradient_loss | -0.000773   |
# |    value_loss           | 10          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 253         |
# |    ep_rew_mean          | 17.9        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 252         |
# |    time_elapsed         | 9047        |
# |    total_timesteps      | 3039232     |
# | train/                  |             |
# |    approx_kl            | 0.009247073 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 3.91        |
# |    n_updates            | 7410        |
# |    policy_gradient_loss | -0.000566   |
# |    value_loss           | 8.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 253         |
# |    ep_rew_mean          | 17.6        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 256         |
# |    time_elapsed         | 9190        |
# |    total_timesteps      | 3055616     |
# | train/                  |             |
# |    approx_kl            | 0.007430142 |
# |    clip_fraction        | 0.0881      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 3.16        |
# |    n_updates            | 7450        |
# |    policy_gradient_loss | -0.0021     |
# |    value_loss           | 8.19        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 259          |
# |    ep_rew_mean          | 17.5         |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 260          |
# |    time_elapsed         | 9333         |
# |    total_timesteps      | 3072000      |
# | train/                  |              |
# |    approx_kl            | 0.0042775525 |
# |    clip_fraction        | 0.0571       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 2e-05        |
# |    loss                 | 3.06         |
# |    n_updates            | 7490         |
# |    policy_gradient_loss | 0.000529     |
# |    value_loss           | 7.67         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 252         |
# |    ep_rew_mean          | 17.3        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 264         |
# |    time_elapsed         | 9477        |
# |    total_timesteps      | 3088384     |
# | train/                  |             |
# |    approx_kl            | 0.008463122 |
# |    clip_fraction        | 0.0736      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 3.72        |
# |    n_updates            | 7530        |
# |    policy_gradient_loss | 0.000889    |
# |    value_loss           | 8.56        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 242        |
# |    ep_rew_mean          | 16.8       |
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 268        |
# |    time_elapsed         | 9621       |
# |    total_timesteps      | 3104768    |
# | train/                  |            |
# |    approx_kl            | 0.00568517 |
# |    clip_fraction        | 0.0508     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | 0.969      |
# |    learning_rate        | 2e-05      |
# |    loss                 | 3.45       |
# |    n_updates            | 7570       |
# |    policy_gradient_loss | 0.000939   |
# |    value_loss           | 9.91       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 240         |
# |    ep_rew_mean          | 16.7        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 272         |
# |    time_elapsed         | 9767        |
# |    total_timesteps      | 3121152     |
# | train/                  |             |
# |    approx_kl            | 0.005777042 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 2e-05       |
# |    loss                 | 3.32        |
# |    n_updates            | 7610        |
# |    policy_gradient_loss | 0.000924    |
# |    value_loss           | 8.42        |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 8
#       5 else:
#       6     model = PPO.load(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}", env=env, print_system_info=True)
# ----> 8 model.learn(total_timesteps=fase3, log_interval=4, reset_num_timesteps=False, progress_bar=True)
#       9 model.save(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}")
#      10 env.close()
#
# File ~/Documentos/AI_Juegos/.venv/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~/Documentos/AI_Juegos/.venv/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:324, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     321 assert self.env is not None
#     323 while self.num_timesteps < total_timesteps:
# --> 324     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     326     if not continue_training:
#     327         break
#
# File ~/Documentos/AI_Juegos/.venv/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:218, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     213     else:
#     214         # Otherwise, clip the actions to avoid out of bound error
#     215         # as we are sampling from an unbounded Gaussian distribution
#     216         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 218 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     220 self.num_timesteps += env.num_envs
#     222 # Give access to local variables
#
# File ~/Documentos/AI_Juegos/.venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:222, in VecEnv.step(self, actions)
#     215 """
#     216 Step the environments with the given action
#     217
#     218 :param actions: the action
#     219 :return: observation, reward, done, information
#     220 """
#     221 self.step_async(actions)
# --> 222 return self.step_wait()
#
# File ~/Documentos/AI_Juegos/.venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      56 def step_wait(self) -> VecEnvStepReturn:
#      57     # Avoid circular imports
#      58     for env_idx in range(self.num_envs):
# ---> 59         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(  # type: ignore[assignment]
#      60             self.actions[env_idx]
#      61         )
#      62         # convert to SB3 VecEnv api
#      63         self.buf_dones[env_idx] = terminated or truncated
#
# Cell In[6], line 29, in CustomRewardWrapper.step(self, action)
#      28 def step(self, action):
# ---> 29     obs, reward, terminated, truncated, info = self.env.step(action)
#      30     #print(f"Reward original: {reward}")
#      31     # Probar mayor penalizacion de agujeros
#      32     custom_reward = reward
#
# File ~/Documentos/AI_Juegos/.venv/lib/python3.10/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/Documentos/AI_Juegos/.venv/lib/python3.10/site-packages/gymnasium/wrappers/stateful_observation.py:426, in FrameStackObservation.step(self, action)
#     417 """Steps through the environment, appending the observation to the frame buffer.
#     418
#     419 Args:
#    (...)
#     423     Stacked observations, reward, terminated, truncated, and info from the environment
#     424 """
#     425 obs, reward, terminated, truncated, info = self.env.step(action)
# --> 426 self.obs_queue.append(obs)
#     428 updated_obs = deepcopy(
#     429     concatenate(self.env.observation_space, self.obs_queue, self.stacked_obs)
#     430 )
#     431 return updated_obs, reward, terminated, truncated, info
#
# KeyboardInterrupt:

# %%
model.save(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}")
env.close()

# %% [markdown]
# # Recording

# %%
try:
  env.close()
except:
  print('no hay env para cerrar')

# %%
env = make_env(game = "tetris_gymnasium/Tetris", render_mode="rgb_array", record = False, obs_type="RGB", increase_height_penalty = 0, increase_holes_penalty = 0, dif_heigh_penalty = 0, line1=0, line2=0, line3=0, line4=0, gameover=0, trunc=0, fase = 4)
try:
  env = RecordVideo(
    env,
    video_folder=f'../Video_Tetris_IA/{Model}',    # Folder to save videos
    name_prefix=f'{Model}_eval-V{version}-Trained_steps_{total_steps}',               # Prefix for video filenames
    episode_trigger=lambda x: True    # Record every episode
  )
except Exception as e:
  print(f'error implementando grabacion: {e}')
if Model == "DQN":
    model = DQN.load(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}", env=env, print_system_info=True)
else:
    model = PPO.load(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}", env=env, print_system_info=True)
# Out:
# /home/seba/Documentos/AI_Juegos/.venv/lib/python3.10/site-packages/gymnasium/wrappers/rendering.py:293:
# UserWarning: WARN: Overwriting existing videos at /home/seba/Documentos/AI_Juegos/Video_Tetris_IA/PPO folder (try
# specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# == CURRENT SYSTEM INFO ==
# - OS: Linux-6.14.0-36-generic-x86_64-with-glibc2.39 # 36~24.04.1-Ubuntu SMP PREEMPT_DYNAMIC Wed Oct 15 15:45:17 UTC
# 2
# - Python: 3.10.19
# - Stable-Baselines3: 2.7.0
# - PyTorch: 2.8.0+cu128
# - GPU Enabled: True
# - Numpy: 1.26.4
# - Cloudpickle: 3.1.1
# - Gymnasium: 1.2.1
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# == SAVED MODEL SYSTEM INFO ==
# - OS: Linux-6.14.0-36-generic-x86_64-with-glibc2.39 # 36~24.04.1-Ubuntu SMP PREEMPT_DYNAMIC Wed Oct 15 15:45:17 UTC
# 2
# - Python: 3.10.19
# - Stable-Baselines3: 2.7.0
# - PyTorch: 2.8.0+cu128
# - GPU Enabled: True
# - Numpy: 1.26.4
# - Cloudpickle: 3.1.1
# - Gymnasium: 1.2.1
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
for episode in range(10):
  state, info = env.reset()
  total_reward = 0
  done = False
  step_count = 0
  while not done:
    step_count+=1
    action, _states = model.predict(state)#, deterministic=True
    state, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    total_reward += reward
  print(f"Episode: {episode} Reward: {total_reward} Steps: {step_count}")
# Out:
# Episode: 0 Reward: 18 Steps: 252
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Episode: 1 Reward: 19 Steps: 251
# Episode: 2 Reward: 21 Steps: 327
# Episode: 3 Reward: 18 Steps: 260
# Episode: 4 Reward: 17 Steps: 242
# Episode: 5 Reward: 17 Steps: 275
# Episode: 6 Reward: 18 Steps: 265
# Episode: 7 Reward: 18 Steps: 242
# Episode: 8 Reward: 18 Steps: 252
# Episode: 9 Reward: 16 Steps: 268

# %% [raw]
# # Assuming 'model' is a trained SB3 agent and 'env' is the VecEnv (e.g., n_envs=4)
#
# n_envs = env.num_envs # Get the number of parallel environments
#
# # Initialize tracking for each parallel environment
# total_rewards = [0.0] * n_envs
# episode_steps = [0] * n_envs
# is_done = [False] * n_envs
# episode_count = 0
#
# # Reset the entire batch of environments
# # state is now a batched observation array of shape (n_envs, ...)
# state= env.reset()
#
# # Continue the loop until all n_envs have completed a full episode (or more)
# while episode_count < 10:
#     # The model predicts actions for the entire batch
#     # action shape is (n_envs, action_space_size)
#     action, _states = model.predict(state, deterministic=True)
#
#     # Step all environments simultaneously
#     # All returns are batched arrays/tensors of size (n_envs, ...)
#     state, reward, terminated, info = env.step(action)
#
#     # Check for termination/truncation (done status)
#     done = terminated
#
#     # --- Update Tracking Metrics ---
#     for i in range(n_envs):
#         # Only update reward and step count if the environment is still active
#         if not is_done[i]:
#             total_rewards[i] += reward[i]
#             episode_steps[i] += 1
#
#             # Check if this specific environment has finished its current episode
#             if done[i]:
#                 print(f"Episode: {episode_count} Reward: {total_rewards[i]:.2f} Steps: {episode_steps[i]}")
#                 episode_count += 1
#
#                 # Reset tracking for the finished environment (in preparation for the next one)
#                 total_rewards[i] = 0.0
#                 episode_steps[i] = 0
#
#                 # IMPORTANT: VecEnvs auto-reset finished environments, so we only need to
#                 # check the condition (episode_count < 10) to stop the loop.
#                 if episode_count >= 10:
#                     break

# %% [markdown]
# # Testing Elements

# %%
# var = len(env.unwrapped.get_state().board)
# count = var
# temp = env.unwrapped.get_state().board[:-4, 4:-4]
# print(temp)
# print(calc_max_height(temp))
# print(calc_holes(temp))
# #print(len(env.unwrapped.get_state().board))

# %%
try:
  env.close()
except:
  print('no hay env para cerrar')

# %%
env = make_env(game = "tetris_gymnasium/Tetris", render_mode="rgb_array", obs_type="RGB", record=False)

# %%
# !pip --version

# %%
import inspect
import tetris_gymnasium.wrappers.observation as obs_module
from tetris_gymnasium.wrappers.observation import RgbObservation

print("Path of the loaded module file:")
print(inspect.getfile(obs_module))
print("\nLocation of the RgbObservation class:")
print(inspect.getfile(RgbObservation))

# %%
env.observation_space

# %%
# from stable_baselines3.common.env_checker import check_env
# check_env(env)

# %%
env.unwrapped.

# %%
env.unwrapped.get_state().board#[:-4, 4:-4]

# %%
np.rot90(np.rot90(np.rot90(env.unwrapped.get_state().board[:-4, 4:-4])))

# %%
height_test = calc_max_height(env.unwrapped.get_state().board[:-4, 4:-4])
print(height_test)
print("-"*20)
print(calc_adj_col(env.unwrapped.get_state().board[:-4, 4:-4], height_test))
print("-"*20)
print(height_test)
print(calc_holes(env.unwrapped.get_state().board[:-4, 4:-4], height_test))

# %%
env = make_env(game = "tetris_gymnasium/Tetris", render_mode="rgb_array")

# %%
env.unwrapped.queue.get_queue()

# %%
#env.unwrapped.active_tetromino
env.unwrapped.collision(tetromino=env.unwrapped.active_tetromino, x=env.unwrapped.x, y=env.unwrapped.y)

# %% [markdown]
# # Testing Grouped

# %%
try:
  env.close()
except:
  print('no hay env para cerrar')

# %%
if __name__ == "__main__":
    env = make_env(game = "tetris_gymnasium/Tetris", render_mode="rgb_array", gravity=False, obs_type="GA")
    if Model == "DQN":
        model = DQN("MlpPolicy", env, buffer_size=BUFFER_SIZE, verbose=1, exploration_fraction=EXPLORATION, learning_rate=LR, batch_size=BATCH_SIZE, gamma=GAMMA) # para Mlp usar FeatureVectorObservation para Cnn usar RgbObservation
    else:
        model = PPO("MlpPolicy", env, verbose=1, n_steps=N_STEPS, clip_range=CLIP_RANGE, ent_coef=ENT_COEF, gamma=GAMMA, batch_size=BATCH_SIZE, learning_rate=LR) # para Mlp usar FeatureVectorObservation para Cnn

    if LOAD_MODEL:
        model.load(model_load_path)
    model.learn(total_timesteps=total_steps, log_interval=4)
    model.save(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}")
    env.close()

# %% [markdown]
# # Testing Feature Vector

# %%
try:
  env.close()
except:
  print('no hay env para cerrar')

# %%
env = make_env(game = "tetris_gymnasium/Tetris", render_mode="rgb_array", obs_type="FV", increase_height_penalty = 1.5, increase_holes_penalty = 1.5, dif_heigh_penalty = 0.05, line1=0.5, line2=0.5, line3=0.5, line4=0.5, gameover=50, trunc=10, fase=1)
if Model == "DQN":
    model = DQN("MlpPolicy", env, buffer_size=BUFFER_SIZE, verbose=1, exploration_fraction=EXPLORATION, exploration_final_eps = 0.05, learning_rate=LR, batch_size=BATCH_SIZE, gamma=GAMMA) # para Mlp usar FeatureVectorObservation para Cnn usar RgbObservation
else:
    model = PPO("MlpPolicy", env, verbose=1, n_steps=N_STEPS, clip_range=CLIP_RANGE, ent_coef=ENT_COEF, gamma=GAMMA, batch_size=BATCH_SIZE, learning_rate=LR) # para Mlp usar FeatureVectorObservation para Cnn

model.learn(total_timesteps=fase1, log_interval=4)
model.save(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}")
env.close()

# %%
env = make_env(game = "tetris_gymnasium/Tetris", render_mode="rgb_array", obs_type="FV", increase_height_penalty = 1.0, increase_holes_penalty = 2.0, dif_heigh_penalty = 0.05, line1=0.5, line2=0.5, line3=0.5, line4=0.5, gameover=50, trunc=10, fase=2)
if Model == "DQN":
    model = DQN.load(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}", env=env, print_system_info=True) 
    model.exploration_rate = 0.3
else:
    model = PPO.load(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}", env=env, print_system_info=True) 

model.learn(total_timesteps=fase2, log_interval=4,reset_num_timesteps=False)
model.save(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}")
env.close()

# %%
env = make_env(game = "tetris_gymnasium/Tetris", render_mode="rgb_array", obs_type="FV", increase_height_penalty = 1.0, increase_holes_penalty = 1.0, dif_heigh_penalty = 0.2, line1=0.5, line2=3, line3=6, line4=15, gameover=50, trunc=10, fase=3)
if Model == "DQN":
    model = DQN.load(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}", env=env, print_system_info=True) 
    model.exploration_rate = 0.3
else:
    model = PPO.load(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}", env=env, print_system_info=True) 

model.learn(total_timesteps=fase3, log_interval=4, reset_num_timesteps=False)
model.save(f"../Models_Saves/{Model}/{Model}_V{version}_S{total_steps}")
env.close()

# %% [markdown]
# # Graficar

# %%
import matplotlib.pyplot as plt
import pandas as pd
df1 = pd.read_csv(f'../Logs/../Logs/{Model}/{Model}_V{version}_S{total_steps}_Fase1.csv.monitor.csv', header=1)
df2 = pd.read_csv(f'../Logs/../Logs/{Model}/{Model}_V{version}_S{total_steps}_Fase2.csv.monitor.csv', header=1)
df3 = pd.read_csv(f'../Logs/../Logs/{Model}/{Model}_V{version}_S{total_steps}_Fase3.csv.monitor.csv', header=1)
df = pd.concat([df1,df2,df3], ignore_index=True)
plt.figure(figsize=(10, 5))
plt.plot(df['l'], label='Episode Length', alpha=0.5)

# Calculate smooth reward (e.g., using a rolling mean)
window_size = 50  # You can adjust this window size
df['smooth_reward'] = df['l'].rolling(window=window_size).mean()
plt.plot(df['smooth_reward'], label=f'Smooth Length', linestyle='--')

plt.xlabel('Episode')
plt.ylabel('Length')
plt.title('Length Graph')
plt.grid(True)
plt.legend()
plt.show()
